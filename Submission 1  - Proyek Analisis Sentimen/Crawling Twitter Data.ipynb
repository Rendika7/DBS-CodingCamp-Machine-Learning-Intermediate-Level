# %% [markdown]
# # Crawl Data Twitter
# The crawling process was done using Tweet-Harvest. Written by Helmi Satria on  March 30th 2024.
#
# Reference :
# https://helmisatria.com/blog/updated-crawl-data-twitter-x-maret-2024

# %%
#@title Twitter Auth Token
twitter_auth_token = '5df0f72af2eaf06aa33a********************' # It's important so I decided not to display this when submitting 🙏

# %% [markdown]
# # Import and install required Python package

# %%
# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 https://deb.nodesource.com/node_20.x nodistro InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Ign:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Hit:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# ...

# %% [markdown]
# # Start Crawl Data Twitter and automatically Saving Data

# %% [markdown]
# Disini saya menggunakan beberapa keyword dengan tema topik Twitternya adalah seputra Hacker yang berhubungan dengan KOMINFO dan pemerintahan Indonesia baru baru ini.
#
# lalu disave dengan nama file yang sesuai jadi nantinya akan masuk kedalam folder `/content/tweets-data/nama_file.csv` lalu setelah itu akan di download kedalam local computer dan upload kedalam drive agar dapat digunakan secara komprehensif.

# %%
Keyword = ['Kominfo Diretas lang:id',
           "BSSN Kominfo lang:id",
           "Brain Cipher Ransomware PDNS lang:id",
           "Budi Arie Mundur lang:id",
           "PDNS Diretas",
           "Kominfo Hacker lang:id",
           "Hacker Indonesia until:2024-12-31 since:2023-01-01",
           "Ancaman Siber Kominfo",
           "kominfo minta maaf",
           "imigrasi backup data",
           "(Peretasan OR PDNS OR Kominfo) until:2024-12-31 since:2022-01-01",
           "131 milyar until:2024-08-31 since:2024-06-01",
           "Hacker minta maaf",
           "(Pemerintah and Hack or hacker)",
           "Keamanan Data Kominfo",
           "Serangan Siber indonesia",
           "Hacker Serang Indonesia until:2024-12-31 since:2023-01-01",
           "(Pemerintah AND Hacker) until:2024-12-31 since:2023-01-01",
           "Hacker PDN",
           "dirjen aptika kominfo",
           "Menkominfo until:2024-12-31 since:2024-01-01"]

Keyword_positive = ['terimakasih menkominfo',
           "menkominfo memuaskan",
           "menkominfo terbaik",
           "alhamdulillah Menkominfo",
           "Menkominfo Berguna",
           "Menkominfo",
           "Kemkominfo",
           "Menkominfo Prestasi",
           "Kementerian Komunikasi dan Informatika",
           "Terimakasih Kominfo",
           "Mentri Kominfo",
           "(Terbaik OR Terimakasih OR Indah OR Bagus)",
           "(suka OR terbaik OR senang OR kualitas OR syukur OR berkualitas OR menarik OR semangat OR cocok)",
           "(bagus OR senang OR kualitas OR syukur OR berkualitas OR menarik OR cocok)"]

Keyword_neutral = ["(netral OR info OR berita OR update OR pengumuman OR fakta OR informasi OR laporan OR berita terbaru OR pemberitahuan OR pengarahan)",
                   "(diskusi OR konten OR artikel OR pembahasan OR pembaruan OR tutorial OR presentasi OR review OR analisis OR proses OR peristiwa)",
                   "(kesehatan OR medis OR penelitian OR terapi OR diagnosis OR perawatan OR konsultasi OR praktik OR kondisi OR pengobatan)",
                   "(pendidikan OR sekolah OR universitas OR kurikulum OR pengajaran OR pelatihan OR materi OR kelas OR silabus OR akademik)",
                   "(olahraga OR pertandingan OR kompetisi OR tim OR latihan OR kondisi fisik OR strategi OR kinerja OR kejuaraan OR turnamen)",
                   "(transportasi OR logistik OR pengiriman OR rute OR kendaraan OR infrastruktur OR mobilitas OR teknologi transportasi OR sistem OR efisiensi)",
                   "(netral OR objektif OR tidak berpihak OR tidak emosional OR tidak memihak OR tidak berat sebelah OR tidak sensitif OR tidak terlibat OR tidak terpaku OR tidak terpengaruh)",
                   "(menurut OR info OR netral OR laporan OR objektif OR proses OR peristiwa)"]

# %%
filename = f'8. [Neutral] - {Keyword_neutral[7]}.csv'
search_keyword = Keyword_neutral[7]
limit = 10000

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1)
# Filling in keywords: (menurut OR info OR netral OR laporan OR objektif OR proses OR peristiwa)
#
#  (2) (3) (4) (5) (6) (7)
#
# Your tweets saved to: /content/tweets-data/8._[Neutral]_-_(menurut_OR_info_OR_netral_OR_laporan_OR_objektif_OR_proses_OR_peristiwa).csv
# Total tweets saved: 15
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/8._[Neutral]_-_(menurut_OR_info_OR_netral_OR_laporan_OR_objektif_OR_proses_OR_peristiwa).csv
# Total tweets saved: 32
#
# -- Scrolling... (1)
#
# ...

# %% [markdown]
# # Loading the result of crawling

# %%
import pandas as pd
import glob
import numpy as np

# %%
# Specify the folder path
folder_path_all_data = "/content/drive/MyDrive/Colab Notebooks/9. DBS Foundation x Dicoding Kelas Menengah 2024/Start Dari 0 Lagi"

# Use glob to find all CSV files in the folder
csv_files = glob.glob(f"{folder_path_all_data}/*.csv")

# %%
count_of_data = []

# Iterate through each file and count the number of rows
for file_path in csv_files:
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(file_path, delimiter=",")

    # Count the number of rows
    num_tweets = len(df)
    count_of_data.append(num_tweets)

    # Print the number of rows for each file
    print(f"Jumlah tweet dalam dataframe '{file_path}' adalah {num_tweets}.")
# Out:
# Jumlah tweet dalam dataframe '/content/drive/MyDrive/Colab Notebooks/9. DBS Foundation x Dicoding Kelas Menengah 2024/Start Dari 0 Lagi/1. [new] Kominfo Diretas-lang_id.csv' adalah 592.
# Jumlah tweet dalam dataframe '/content/drive/MyDrive/Colab Notebooks/9. DBS Foundation x Dicoding Kelas Menengah 2024/Start Dari 0 Lagi/1. [old] Kominfo Diretas-lang_id.csv' adalah 566.
# Jumlah tweet dalam dataframe '/content/drive/MyDrive/Colab Notebooks/9. DBS Foundation x Dicoding Kelas Menengah 2024/Start Dari 0 Lagi/10._imigrasi_backup_data.csv' adalah 60.
# Jumlah tweet dalam dataframe '/content/drive/MyDrive/Colab Notebooks/9. DBS Foundation x Dicoding Kelas Menengah 2024/Start Dari 0 Lagi/11._(Peretasan_OR_PDNS_OR_Kominfo)_until-2024-12-31_since-2022-01-01.csv' adalah 394.
# Jumlah tweet dalam dataframe '/content/drive/MyDrive/Colab Notebooks/9. DBS Foundation x Dicoding Kelas Menengah 2024/Start Dari 0 Lagi/3. Brain Cipher Ransomware PDNS-lang_id.csv' adalah 45.
# ...

# %% [markdown]
# # Cek jumlah data yang didapatkan

# %%
np.sum(count_of_data)
# Out:
# 41627

# %%
total_data = np.sum(count_of_data)
target_data = 10000

if total_data >= target_data:
  print(f"Total Data Saat ini = {total_data} dan sudah melebihi target sebanyak {abs(target_data - total_data)}")
else:
  print(f"Total Data Saat ini = {total_data} dan kurang {target_data - total_data} data untuk mencapai Target")
# Out:
# Total Data Saat ini = 41627 dan sudah melebihi target sebanyak 31627

# %% [markdown]
# # Processing Dataset untuk Labeling

# %%
# Read all CSV files into a list of dataframes
dataframes = [pd.read_csv(file) for file in csv_files]

# %%
print(f"Total file hasil scraping = {len(dataframes)} file berekstensi .csv")
# Out:
# Total file hasil scraping = 57 file berekstensi .csv

# %%
# Assign each dataframe to a variable named df1, df2, df3, etc.
for i, df in enumerate(dataframes):
    globals()[f'df{i+1}'] = df

# %%
# Verify by printing the first few rows of each dataframe
for i in range(1, len(dataframes) + 1):
    print(f'df{i} head:')
    display(globals()[f'df{i}'].head(2))
    print('\n')
# Out:
# df1 head:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1808031920657195434  Tue Jul 02 06:56:16 +0000 2024               0
# 1  1808031167217914312  Tue Jul 02 06:53:16 +0000 2024               0
#
#                                            full_text               id_str  \
# 0  Kenapa Kominfo Pe-de bhw tdk bocor datanya ? k...  1808031920657195434
# 1  Data Kementerian Kominfo yang tersimpan di Pus...  1808031167217914312
#
#                                          image_url in_reply_to_screen_name  \
# 0                                              NaN                     NaN
# 1  https://pbs.twimg.com/media/GRdqwOsagAAIpKH.jpg                     NaN
#
#   lang location  quote_count  reply_count  retweet_count  \
# 0   in    E.G.P            0            0              0
# 1   in  Jakarta            0            0              0
#
#                                            tweet_url          user_id_str  \
# ...

# %% [markdown]
# ## Combine All Datasets into 1 Dataframe

# %%
# Concatenate all dataframes into one dataframe named train. karena mau digunakan untuk melatih model nantinya, tinggal di apply label saja. menggunakan beberapa metode seperti Rule Based or maybe Predict from Transformers
additional_train = pd.concat(dataframes, ignore_index=True)

# %%
Processed_additional_train = additional_train[["full_text", "location", "tweet_url", "username"]]

# %%
additional_train[["full_text", "location", "tweet_url", "username"]].to_csv(folder_path_all_data + "/Data After Labeling/All Data Combined.csv")

# %%
print(f'Pada data hasil scraping mengalami duplikat data sebanyak {Processed_additional_train.duplicated(subset = "full_text").sum()} jadi akan dilakukan pengahpusan data duplikat')
Processed_additional_train = Processed_additional_train.drop_duplicates(subset = "full_text").reset_index(drop=True).dropna(subset = "full_text")
print(f'Setelah dibersihkan sekarang data duplikat sudah menjadi {Processed_additional_train.duplicated(subset = "full_text").sum()}')
# Out:
# Pada data hasil scraping mengalami duplikat data sebanyak 11978 jadi akan dilakukan pengahpusan data duplikat
# Setelah dibersihkan sekarang data duplikat sudah menjadi 0

# %%
print(f'Setelah dibersihkan total hasil scraping twitter adalah sebanyak {Processed_additional_train.shape[0]} baris, dan {Processed_additional_train.shape[1]} kolom')
# Out:
# Setelah dibersihkan total hasil scraping twitter adalah sebanyak 29648 baris, dan 4 kolom

# %% [markdown]
# # **Make a Label for every Tweets, based on just one columns which is "full_text"**

# %% [markdown]
# [Refrensi Labeling Text](https://www.kaggle.com/code/ludovicocuoghi/how-are-people-reacting-to-omicron-on-twitter#Positive-Tweets-Analysis-by-algorithm)

# %% [markdown]
# ## 1) Rule Based Labeling

# %% [markdown]
# Polarity Score didapatkan dari github: https://github.com/fajri91/InSet

# %%
# !pip install sastrawi nlp-id
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 68.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.6/402.6 kB 31.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 52.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 78.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 19.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9656 sha256=172b1534bad61a260312bd2c36ef131bda8dc2dadc15ec2cd16829e50cd26d79
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
# ...

# %%
import nltk # Natural Language Toolkit - Library for natural language processing (NLP) tasks such as tokenization, stemming, tagging, parsing, and more.
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from tqdm import tqdm # A Fast, Extensible Progress Bar - Library for creating progress bars to monitor the progress of iterations or tasks.
from nltk.stem import WordNetLemmatizer, PorterStemmer

from nlp_id.lemmatizer import Lemmatizer
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.feature_extraction.text import CountVectorizer
import os

# %%
mainPath = "/content/drive/MyDrive/Colab Notebooks/9. DBS Foundation x Dicoding Kelas Menengah 2024"
dataPath = os.path.join(mainPath, "Data Final Result")
additionalPath = os.path.join(mainPath, "Additional Data")

# %%
lexicon_corpus = pd.read_excel(additionalPath + "/colloquial-indonesian-lexicon.xlsx", sheet_name="Clean-Colloquial-Lexicon")
stopword_corpus = pd.read_excel(additionalPath + "/Stopword.xlsx")

# %% [markdown]
# ### Cleaning Text

# %%
Processed_additional_train
# Out:
#                                                full_text  \
# 0      Kenapa Kominfo Pe-de bhw tdk bocor datanya ? k...
# 1      Data Kementerian Kominfo yang tersimpan di Pus...
# 2      PDNS 2 Diretas Kominfo Targetkan Full Recovery...
# 3      Konon BSSN tlah menginfokan ke kominfo bakal a...
# 4      Rakyat juga lihat tindak tandukmu yang cawe ca...
# ...                                                  ...
# 29644  @Poulin2012 Suspicion d'information. Cher Alex...
# 29645                               @otamani_info 応募しました
# 29646  @FIFA22_INFO The new fifa is going to bury the...
# 29647  @chae02939 트 위터 에서 은ㄲ짤 찾는 ㅅ트러 분 들께선 @man_secre...
# 29648  Confira Quer Ajuda Para Escolher uma Profissão...
#
#                              location  \
# 0                               E.G.P
# 1                             Jakarta
# 2                             Jakarta
# 3                                 58%
# 4              DKI Jakarta, Indonesia
# ...                               ...
# ...

# %%
import re
import string

def clean_text(text):
    text = text.lower()
    text = re.sub(r'@\w+', '', text)
    text = re.sub(r'https?://\S+', '', text)
    text = re.sub(r'www\.\S+', '', text)
    text = re.sub(r'\d+', '', text)
    text = text.encode('ascii', 'ignore').decode('ascii')
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = re.sub(r'\s+', ' ', text).strip()
    text = ' '.join([word for word in text.split() if len(word) > 1])

    return text

# %%
Processed_additional_train['text_clean'] = Processed_additional_train['full_text'].apply(clean_text)

# %%
Processed_additional_train.head()
# Out:
#                                            full_text                location  \
# 0  Kenapa Kominfo Pe-de bhw tdk bocor datanya ? k...                   E.G.P
# 1  Data Kementerian Kominfo yang tersimpan di Pus...                 Jakarta
# 2  PDNS 2 Diretas Kominfo Targetkan Full Recovery...                 Jakarta
# 3  Konon BSSN tlah menginfokan ke kominfo bakal a...                     58%
# 4  Rakyat juga lihat tindak tandukmu yang cawe ca...  DKI Jakarta, Indonesia
#
#                                            tweet_url      username  \
# 0  https://x.com/Nor_Mantri/status/18080319206571...    Nor_Mantri
# 1  https://x.com/BloombergTZ/status/1808031167217...   BloombergTZ
# 2  https://x.com/okezonenews/status/1808031122502...   okezonenews
# 3  https://x.com/toe_giman/status/180798853369900...     toe_giman
# 4  https://x.com/jhony23purba/status/180797627523...  jhony23purba
#
#                                           text_clean
# ...

# %% [markdown]
# ### Paired Lexicon

# %%
# drop nilai nan di dalam corpus lexicon, yang kata formalnya tidak ada
lexicon_corpus = lexicon_corpus.dropna(subset=['formal'])
lexicon_corpus = lexicon_corpus.drop_duplicates(subset=['slang'])

# %%
def replace_slang(text, slang_formal_pairs):
    for slang, formal in slang_formal_pairs:
        text = re.sub(r'\b{}\b'.format(re.escape(slang)), formal, text)
    return text

slang_formal_pairs = list(zip(lexicon_corpus['slang'], lexicon_corpus['formal']))

# %%
# Fungsi untuk membersihkan teks
def clean_text(text, slang_formal_pairs = slang_formal_pairs):
    # Lowercasing
    text = text.lower()
    # Mengganti kata-kata dengan kata yang sesuai dari lexicon_corpus
    text = replace_slang(text, slang_formal_pairs)

    return text

# %%
# Menerapkan fungsi ke kolom text
Processed_additional_train['text_clean_2'] = Processed_additional_train['text_clean'].apply(clean_text)

# %% [markdown]
# ### Stemming & Stopword Removal

# %%
# Download stopwords and wordnet
nltk.download(['stopwords', 'wordnet'])

# Initialize Sastrawi stemmer
factory = StemmerFactory()
stemmer_sastrawi = factory.create_stemmer()

# Define stop words from NLTK
stop_words_nltk = set(stopwords.words('indonesian'))

# Define additional stop words from Sastrawi or custom corpus
stop_words_sastrawi = set(stopword_corpus["Stopword"])

# Combine stop words
stop_words = stop_words_nltk.union(stop_words_sastrawi)

# Print the combined stop words
# stop_words
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
# Define the preprocessing function
def preprocess_text(text):
    if not isinstance(text, str):
        return ""

    # Tokenize the text into words
    words = text.split()

    # Remove stopwords and apply stemming
    processed_words = []
    for word in words:
        if word.lower() not in stop_words:  # NLTK Stopword
            stemmed_word = stemmer_sastrawi.stem(word)  # Sastrawi Stemming
            processed_words.append(stemmed_word)

    # Join the processed words back into a single string
    return " ".join(processed_words)

# %%
Processed_additional_train['text_clean_3'] = Processed_additional_train['text_clean_2'].astype(str).apply(preprocess_text)

# %% [markdown]
# ### Applying Polarity Score

# %%
lexicon_positive = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/9. DBS Foundation x Dicoding Kelas Menengah 2024/Additional Data/positive.csv')
lexicon_negative = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/9. DBS Foundation x Dicoding Kelas Menengah 2024/Additional Data/negative.csv')

lexicon_negative = lexicon_negative.rename(columns = {" word":"word"})
lexicon_positive = lexicon_positive.rename(columns = {" word":"word"})

# %%
# Konversi lexicon ke dictionary
lexicon_positive_dict = dict(zip(lexicon_positive['word'], lexicon_positive['weight']))
lexicon_negative_dict = dict(zip(lexicon_negative['word'], lexicon_negative['weight']))

# %%
def labeling(kalimat):
    score = 0
    words = kalimat.split()
    for word in words:
        if word in lexicon_positive_dict:
            score += lexicon_positive_dict[word]
        if word in lexicon_negative_dict:
            score += lexicon_negative_dict[word]

    if score > 0:
        polarity = 'positive'
    elif score == 0:
        polarity = 'neutral'
    else:
        polarity = 'negative'

    return score, polarity

# %%
# Aplikasikan fungsi labeling pada kolom text
Processed_additional_train[['polarity_score', 'label based on polarity']] = Processed_additional_train['text_clean_3'].apply(lambda x: pd.Series(labeling(x)))

# %%
Processed_additional_train["label based on polarity"].value_counts()
# Out:
# label based on polarity
# negative    19163
# positive     7731
# neutral      2754
# Name: count, dtype: int64

# %%
Processed_additional_train.head(3)
# Out:
#                                            full_text location  \
# 0  Kenapa Kominfo Pe-de bhw tdk bocor datanya ? k...    E.G.P
# 1  Data Kementerian Kominfo yang tersimpan di Pus...  Jakarta
# 2  PDNS 2 Diretas Kominfo Targetkan Full Recovery...  Jakarta
#
#                                            tweet_url     username  \
# 0  https://x.com/Nor_Mantri/status/18080319206571...   Nor_Mantri
# 1  https://x.com/BloombergTZ/status/1808031167217...  BloombergTZ
# 2  https://x.com/okezonenews/status/1808031122502...  okezonenews
#
#                                           text_clean  \
# 0  kenapa kominfo pede bhw tdk bocor datanya krn ...
# 1  data kementerian kominfo yang tersimpan di pus...
# 2  pdns diretas kominfo targetkan full recovery p...
#
#                                         text_clean_2  \
# 0  kenapa kominfo percaya diri bahwa tidak bocor ...
# 1  data kementerian kominfo yang tersimpan di pus...
# 2  pdns diretas kominfo targetkan penuh recovery ...
#
# ...

# %%
# Processed_additional_train.to_csv(folder_path_all_data + "/Data After Labeling/Labeling Data Based on Lexicon Polarity.csv")

# %% [markdown]
# ## 2) Transformers Model Labeling

# %% [markdown]
# model used :
# - https://huggingface.co/ayameRushia/bert-base-indonesian-1.5G-sentiment-analysis-smsa
#
# - https://huggingface.co/mdhugol/indonesia-bert-sentiment-classification

# %%
import transformers
print("Transformers version:", transformers.__version__)
from transformers import pipeline

sentiment_task  = pipeline(
    model="mdhugol/indonesia-bert-sentiment-classification",
    return_all_scores=True
)
# Out:
# Transformers version: 4.42.4
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/498M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/229k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ...

# %%
def predict_sentiment(df):
    # Create empty lists to store results
    id_sentiments = []
    id_scores = []

    # Iterate over each row in the dataframe
    for index, row in df.iterrows():
        # Predict sentiment for id_full_text
        id_result = sentiment_task(row['text_clean_3'])
        result = id_result[0]
        # Find the index of the highest score
        max_score_index = max(range(len(result)), key=lambda i: result[i]['score'])

        # Extract the label and highest score
        max_label = result[max_score_index]['label']
        max_score = result[max_score_index]['score']

        id_sentiments.append(max_label)
        id_scores.append(max_score)

    # Add sentiment and score columns to the dataframe
    df['label based on roBERTa Model'] = id_sentiments
    df['sentiment score'] = id_scores

    return df

# %%
Processed_additional_train = predict_sentiment(Processed_additional_train)

# %%
# Dictionary to replace labels
label_replace = {
    'LABEL_0': 'positive',
    'LABEL_1': 'neutral',
    'LABEL_2': 'negative'
}

# Replace labels in the DataFrame
Processed_additional_train['label based on roBERTa Model'] = Processed_additional_train['label based on roBERTa Model'].replace(label_replace)

# %%
# Processed_additional_train.to_csv(folder_path_all_data + "/Data After Labeling/Labeling Data Based on [BERT Transformers] and [Lexicon Polarity].csv", index= False)

# %%
Processed_additional_train = pd.read_csv(folder_path_all_data + "/Data After Labeling/Labeling Data Based on [BERT Transformers] and [Lexicon Polarity].csv")

# %%
# Processed_additional_train = Processed_additional_train.dropna(subset = "text_clean_3").drop_duplicates(subset = "text_clean_3").reset_index(drop=True).drop(columns = ["Unnamed: 0.1",	"Unnamed: 0"])

# %%
Processed_additional_train
# Out:
#                                                full_text  \
# 0      Kenapa Kominfo Pe-de bhw tdk bocor datanya ? k...
# 1      Data Kementerian Kominfo yang tersimpan di Pus...
# 2      PDNS 2 Diretas Kominfo Targetkan Full Recovery...
# 3      Konon BSSN tlah menginfokan ke kominfo bakal a...
# 4      Rakyat juga lihat tindak tandukmu yang cawe ca...
# ...                                                  ...
# 26889  @futebol_info Imagina a felicidade q é acordar...
# 26890  Mándenme uno de esos también quiero seguir mul...
# 26891  @Poulin2012 Suspicion d'information. Cher Alex...
# 26892  @FIFA22_INFO The new fifa is going to bury the...
# 26893  Confira Quer Ajuda Para Escolher uma Profissão...
#
#                              location  \
# 0                               E.G.P
# 1                             Jakarta
# 2                             Jakarta
# 3                                 58%
# 4              DKI Jakarta, Indonesia
# ...                               ...
# ...

# %% [markdown]
# # Selection and Validation the result of labeling

# %%
Processed_additional_train = pd.read_csv(folder_path_all_data + "/Data After Labeling/Labeling Data Based on [BERT Transformers] and [Lexicon Polarity].csv")

# %%
Processed_additional_train["label based on roBERTa Model"].value_counts()
# Out:
# label based on roBERTa Model
# neutral     12789
# negative     8425
# positive     5680
# Name: count, dtype: int64

# %%
Processed_additional_train["label based on polarity"].value_counts()
# Out:
# label based on polarity
# negative    17625
# positive     7062
# neutral      2207
# Name: count, dtype: int64

# %% [markdown]
# Pada hasil pe-labelin diatas, mungkin yang lebih benar adalah yang menggunakan polarity. karena saya pribadi saat scraping memang menggunakan keyword yang sedang viral dan viral akan kejelakannya jadi sewajarnya negative sangat tinggi. jadi saya akan ambil yang label based on polarity.

# %%
Processed_additional_train1 = Processed_additional_train[['full_text', 'label based on polarity', 'polarity_score']]
Processed_additional_train2 = Processed_additional_train[['full_text', 'label based on roBERTa Model', 'sentiment score']]

# %%
Processed_additional_train1.to_csv(folder_path_all_data + "/Data After Labeling/train_based_on_polarity_score.csv")
Processed_additional_train2.to_csv(folder_path_all_data + "/Data After Labeling/train_based_on_bert_transformers.csv")

# %%
Processed_additional_train1 = pd.read_csv(folder_path_all_data + "/Data After Labeling/train_based_on_polarity_score.csv")
Processed_additional_train2 = pd.read_csv(folder_path_all_data + "/Data After Labeling/train_based_on_bert_transformers.csv")

# %%
Processed_additional_train1["label based on polarity"].value_counts()
# Out:
# label based on polarity
# negative    17625
# positive     7062
# neutral      2207
# Name: count, dtype: int64

# %%
Processed_additional_train2["label based on roBERTa Model"].value_counts()
# Out:
# label based on roBERTa Model
# neutral     12789
# negative     8425
# positive     5680
# Name: count, dtype: int64

# %% [markdown]
# Disini terlihat untuk Transformers dan Ruled Based Labeling sepertinya lebih baik dalam Balancing nya di pihak Transformers. jadi saya langsung menggunakan Milik Transformers saja. karena imbalanced data di Ruled Based Labeling terlalu tinggi.
